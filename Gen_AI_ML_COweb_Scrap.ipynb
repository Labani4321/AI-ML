# %% [markdown]
# <a href="https://colab.research.google.com/github/Labani4321/AI-ML/blob/main/Gen_AI_ML_COweb_Scrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Important** **Libraries**
# Do a check to gain more information about requests module: https://www.w3schools.com/python/module_requests.asp
#
# Know More about Python List: https://www.w3schools.com/python/python_lists.asp, https://www.w3schools.com/python/python_lists_access.asp
#
# If you want to know more about BeautifulSoup : https://beautiful-soup-4.readthedocs.io/en/latest/
#
# **Not possible to cover every concept today,but I can give you the basic understanding about it: 🙂**
#
# You can always remove the '#' and run the following commands , also '#' is used to make a comment in python

# %%
import requests
from bs4 import BeautifulSoup as bsp
import pandas as pd

# %%
requests.get('https://internshala.com/internships/','html.parser')
# Out:
# <Response [200]>

# %%
requests.get('https://internshala.com/internships/','html.parser').content
# Out:
# b'<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:fb="https://www.facebook.com/2008/fbml"\n      lang="en-US">\n\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=9" />\n    <meta charset="UTF-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1.0 user-scalable=0" />\n    <meta property="fb:app_id" content="702141670710132" />\n    <meta property="og:type" content="website" />\n        <meta property="og:image:width" content="1200" />\n    <meta property="og:image:height" content="630" />\n    <link rel="preload" href="https://internshala.com//static/images/home/sprites/img-assets.png" as="image"/>\n<link rel="preload" as="image" href="https://internshala.com//static/images/internship/banners/jobs_banner_r767.png" media="(max-width: 767px)"/>\n<link rel="preload" as="image" href="https://internshala.com//static/images/internship/banners/jobs_banner_r1920.png" media="(min-width: 767.1px)"/>    <meta name="twitter:site" content="@Internshala" />\n        <meta name="twitter:card" content="summary_large_image" />\n    \n    <meta name="twitter:creator" content="@internshala" />\n        <meta name="theme-color" content="#ffffff" />\n    <meta name="msapplication-navbutton-color" content="#ffffff" />\n    <meta name="format-detection" content="telephone=no" />\n\n        <link as="font" href="/static/fonts/Inter.woff2?v=3.11" type="font/woff2" crossorigin />\n    <link as="font" href="/static/fonts/internshala-icons.woff2?vw3rgh" type="font/woff2"  crossorigin />    <script src="/static/js/web_vitals/web-vitals.umd.js"></script>\n    <script src="/static/js/includes/common/libraries.2583691470.js" defer></script>\n       <link rel="stylesheet" href="https://internshala.com//static/cdn/4.4.1/css/bootstrap.min.css" />\n    \n    <link rel="icon" href="https://internshala.com//favicon.ico?v=5" />\n    <script nonce="YyqjQ7b/o4iVffOzkJ9I0A==">\n    window.onerror = function (error, url, line, col, fullError) {\n        error = fullError || error;\n        store_data(error, line);\n    };\n\n    function store_data(error, line) {\n        error = error.stack || error;\n        var url = window.location.href;\n        var browser = get_browser();\n        var browser_name = browser.name;\n        var browser_version = browser.version;\n        var browser_ua = browser.user_agent;\n        var message = "error=" + error + ". Line:" + line + "&browser=" + browser_name + "&version=" + browser_version + "&url=" + url + "&ua=" + browser_ua;\n        // var xhttp = new XMLHttpRequest();\n        // xhttp.onreadystatechange = function () {\n        //     if (this.readyState === 4 && this.status === 200) {\n\n        //     }\n        // };\n        // xhttp.open("POST", "/browser_error/insert_browser_logs", true);\n        // xhttp.setRequestHeader(\'X-Requested-With\', \'XMLHttpRequest\');\n        // xhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");\n        // xhttp.send(message);\n    }\n\n    function get_browser() {\n        var ua = navigator.userAgent, tem, M = ua.match(/(opera|chrome|safari|firefox|msie|trident(?=\\/))\\/?\\s*(\\d+)/i) || [];\n        if (/trident/i.test(M[1])) {\n            tem = /\\brv[ :]+(\\d+)/g.exec(ua) || [];\n            return {name: \'IE\', version: (tem[1] || \'\')};\n        }\n        if (M[1] === \'Chrome\') {\n            tem = ua.match(/\\bOPR|Edge\\/(\\d+)/)\n            if (tem != null) {\n                return {name: \'Opera\', version: tem[1]};\n            }\n        }\n        M = M[2] ? [M[1], M[2]] : [navigator.appName, navigator.appVersion, \'-?\'];\n        if ((tem = ua.match(/version\\/(\\d+)/i)) != null) {\n            M.splice(1, 1, tem[1]);\n        }\n        return {\n            name: M[0],\n            version: M[1],\n            user_agent: ua\n        };\n    }\n</script>\n    <script nonce="YyqjQ7b/o4iVffOzkJ9I0A==">\n    var os_type = "";\n    var browser_name = \'pytho ...

# %%
url='https://internshala.com/internships/'

# %% [markdown]
# **Getting Responses from the website**

# %%
resp=requests.get(url,'html.parser')
print(resp.status_code)
# Out:
# 200

# %%
fieldname=input("Enter your profile : ")
# Out:
# Enter your profile : web development

# %%
field=fieldname.replace(' ','-')

# %% [markdown]
# **URL Handling**

# %%
modified_url=url+str(field)+'-internship/'
print(f"Status :{requests.get(modified_url)}")
print(modified_url)
# Out:
# Status :<Response [200]>
# https://internshala.com/internships/web-development-internship/

# %%
resp_new=requests.get(modified_url)

# %%
soup=bsp(resp_new.content,'html.parser')
#print(soup)

# %%
# type(soup)

# %%
pages=int(soup.find('span',id='total_pages').text)
# print(pages)

# %%
urlList = []
page = 1
while page <= pages:
  newUrl = modified_url+str(f"page-{page}/")
  urlList.append(newUrl)
  page +=1
# print(urlList)

# %%
soup2 = []
for url in urlList:
  resp_new=requests.get(url)
  soup3=bsp(resp_new.content,'html.parser')
  soup2.append(soup3)
# print(len(soup2))

# %%
# print(soup.prettify())

# %% [markdown]
# **Scraping**

# %%
name=[]
for soup in soup2:
  names=soup.find_all('div',class_='individual_internship_header')
  for i in names:
    name.append(i)
# print(len(name))
#print(name)

# %%
# print(type(name))
# profile=name.find_all('h3',class_='heading_4_5 profile')

# %%
# for i in name:
#   p=i.find('h3',class_='heading_4_5 profile')
  # print(p)
  # print(p.text)
  # print(p.text.strip())
  # break

# %%
profile=[]
for i in name:
  p=i.find('h3',class_='heading_4_5 profile')
  # print(p)
  # print(p.text)
  # print(p.text.strip())
  a=p.text.strip()
  profile.append(a)
  #break
# print(len(profile))
print(f"All profiles available are : {profile}")
# Out:
# All profiles available are : ['Web Development', 'PHP Development', 'Demo Post', 'Flutter Development', 'IT Support', 'WordPress Development', 'PHP Development', 'Full Stack Php Developer', 'Flutter Development', 'PHP Development', 'Flutter Development', 'Shopify Developer', 'WordPress Development', 'E Commerce Web App Development Using Next Js/React JS And Node JS', 'Front End Development', 'Front End Development', 'Augmented Reality/ Virtual Reality Developer', 'Frontend Development', 'PHP Development', 'Backend Development', 'Full Stack Development', 'WordPress Development', 'Node.js Development', 'WordPress Development', 'Front End Development', 'PHP Development', 'Web Development', 'Laravel Development', 'PHP Development', 'Project Manager', 'Blockchain Development', 'Wix/WordPress Website Designer', 'Reactjs Development', 'System Admininstrator', 'Information Technology', 'Web Development', 'PHP Development', 'Python Development', 'CSS And HTML Developer', 'Full Stack Developer', 'IT Assistant Intern', 'Python Development', 'Backend Development', 'Flutter Development', 'Web Development', 'Web Development', 'Web Scrapping', 'Web Development', 'Django Selenium.', 'Reactjs Development', 'WordPress Development', 'Django Developer', 'Wordpress + Shopify', 'Backend Development', 'PHP Development', 'Flutter Development', 'WordPress Development', 'Angular Development', 'JavaScript Development', 'Node.js Development', 'WordPress Development', 'Flutter Development', 'Python Development', 'Asp.net Development', 'Computer Operator (Online Tender Bidding On Gem Portal)', 'React Native/ React Js', 'Full Stack Development', 'AI Flutter Developer', 'Backend Development', 'Full Stack Development', 'Front End Development', 'Information Technology', 'Front End Development', 'PHP Development', 'Reactjs Development', 'Backend & ML Development', 'Web Development', 'Python Full Stack Development', 'Blockchain Development', 'Native Application Developer', 'Full Stack Development', 'Web Development', 'Web Development', 'Web Development', 'Java Web Developer/Mobile App Developer', 'Laravel', 'Django', 'PHP Development', 'Quantitative Developer', 'Full Stack Development', 'Reactjs Development', 'Full Stack Development', 'Full Stack ML Engineering/Python & Flask Web Development', 'Java Development', 'ChatBot Development', 'Web3 Developer', 'Webflow Designer And Developer', 'JavaScript Development', 'Flutter Development', 'Webflow Designer And Developer', 'Babylon.js Developer', 'Python Development', 'Front End Development', 'Front End Development', 'Full Stack Development', 'Web Development', 'JavaScript Development', 'Reactjs Development', 'PHP Laravel', 'Three.js Developer', 'Full Stack Development', 'Flutter Development', 'Backend Development', 'React Native Developer', 'WordPress Development', 'WordPress Website Developer & Conversion Optimization Specialist', 'Reactjs Development', 'Front End Development', 'PHP Development', 'Flutter Development', 'Front End Development', 'Full Stack Development', 'WordPress Development', 'Web3 Management', 'Flutter Development', 'Full Stack Data Engineering', 'Web Scraping Internship', 'Full Stack Development', 'Java Development', 'Backend Development', 'Full Stack Development', 'Web Development', 'Flutter Development', 'React Native Development', 'Web Development', 'WordPress Development', 'Backend Development', 'Webflow', 'Full Stack Development', 'Ruby Software Developer', 'Backend Development', 'PHP Development', 'Web Development', 'Full Stack Development', 'Node.js Development', 'Reactjs Development', 'Front End Development', 'Backend Development', 'Python Development', 'Chrome Extension And Next.js Development', 'Full Stack Development', 'PHP Development', 'Reactjs Development', 'Front End Development', 'Python Development', 'WordPress Development', 'Web Development', 'Reactjs Development', 'WordPress Development', 'Frontend Developer Intern', 'WordPress, ReactJS, NoCode Platforms Design & Development', ...

# %%
company=[]
for i in name:
  com=i.find('p').text.strip()
  #print(com)
  company.append(com)
# print(len(company))
print(company)
# Out:
# ['Stirring Minds', 'UI TECH LAB LLP', 'Seven Arc Info Systems LLP', 'AppyHigh Technology', 'Vigorous Healthtech Private Limited', 'Schnell Labs', 'UI TECH LAB LLP', 'Brandzzy SoftTech Private Limited', 'Antino Labs Private Limited', 'Ansh Intertrade Private Limited', 'Repsoft Consultancy Services Private Limited', 'Axe Consultancy And Security Services LLC', 'Shivam Arora', 'MyMegaminds', 'UI TECH LAB LLP', 'UI TECH LAB LLP', 'Indian Institute Of Technology, Bombay', 'GlobFluent VidyaTech Pvt. Ltd.', 'Evoort Solutions', 'Idea Usher', 'KVAR Technologies Private Limited', 'Zenchi Softwares (OPC) Private Limited', 'Faclon', 'Aditya Raj', 'Baygrape Technology Solutions', 'International Institute Of Financial Markets (Pratham)', 'Fyle', 'Codalay', 'Intella Education Private Limited', 'GODECOR TECHNOLOGIES PRIVATE LIMITED', 'Tensorblue', 'Tensorblue', 'Digital Gimmick', 'ITechServ', 'ClearTax', 'Amak Solution', 'OyeLabs', 'Aester India Private Limited', 'Smaclify Technologies', 'Dobby Ads', 'Cleantech Solar', 'Medius Technologies Private Limited', 'Adisri Publications Private Limited', 'Coding Junior', 'IPistis Technologies Private Limited', 'IndianAppGuy Tech Private Limited', 'Medius Technologies Private Limited', 'Pearl Lemon (London, United Kingdom)', 'Medius Technologies Private Limited', 'Medius Technologies Private Limited', 'Hawk Digital Agency', 'Medius Technologies Private Limited', 'Rank Revenue Digitech', 'DataChannel Technologies', 'Coding Junior', 'K4 Media & Technologies', 'Gamahouse Publishing', 'Pianalytix Edutech Private Limted', 'W3Dev', 'Pianalytix Edutech Private Limted', 'WishWorks Solutions Private Limited', 'Pianalytix Edutech Private Limted', 'Pianalytix Edutech Private Limted', 'EVz', 'G&T-Star Production And Entertainment Private Limited', 'Linked List Technologies LLP', 'Zimeshare Technologies (OPC) Private Limited', 'Systemic Altruism', 'Medius Technologies Private Limited', 'NovaFocus Private Limited', 'Fabulous Media Private Limited', 'Brain Wave AI Solutions', 'AI Certs', 'SoftSolvate', 'MoLog Media & Advertising', 'COSGrid Systems Private Limited', 'Buddha Education Association Incorporation', 'Blackcoffer', 'Buddha Education Association Incorporation', 'TeraBucket', 'Techvolt Software Private Limited', 'Techvolt Software Private Limited', 'Watrana Traction Private Limited', 'Medius Technologies Private Limited', 'Samyak Tech Labs', 'WebCraft IT', 'Varsity Pro', 'Business Labs', 'Mudraksh And McShaw Advisory', 'Algo Div', 'Tensorblue', 'The AI Hub', 'Dendrite.ai', 'Pianalytix Edutech Private Limted', 'Pianalytix Edutech Private Limted', 'Alecado Systems', 'Stirring Minds', 'Pianalytix Edutech Private Limted', 'Schaffen Softwares', 'Stirring Minds', 'Alecado Systems', 'Bright Infonet', 'Ramyoz', 'FlowLaunch', 'Uniqgrid', 'Conscript HR Advisors Private Limited', 'Conscript HR Advisors Private Limited', 'Across The Globe (ATG)', 'Across The Globe (ATG)', 'Alecado Systems', 'Alecado Systems', 'OyeLabs', 'Workik', 'Blackcoffer', 'Brihat Infotech Private Limited', 'Vanillakart', 'Amdigit', 'React Labs Private Limited', 'Quantum IT Innovation', 'Quantum IT Innovation', 'Quantum IT Innovation', 'Quantum IT Innovation', 'Career Guideline Services India Private Limited', 'Blazpay Labs Corp', 'Systemic Altruism', 'Blackcoffer', 'Webmobi', 'L2BC', 'NatWest Group', 'Techwondoe India Private Limited', 'Bezt Labs', 'Celebrare', 'Celebrare', 'Across The Globe (ATG)', 'Across The Globe (ATG)', 'Travelomatrix', 'Systemic Altruism', 'Systemic Altruism', 'Systemic Altruism', 'Peach', 'Flint Merchandising LLP', 'Dakshith Technologies', 'MentorBoxx', 'EYTHOR PRIVATE LIMITED', 'Across The Globe (ATG)', 'Close Digit LLP', 'Worko.ai', 'Worko.ai', 'Bamigos', 'Solocl', 'PiSence Technologies LLP', 'Bytive Technologies Private Limited', 'Stackwit (OPC) Private Limited', 'OCPL Tech (Opulentia Cresco Private Limited)', 'Warewe Consultancy Private Limited', 'Blackcoffer', 'Chatcells', 'IWebcode', 'Confluencr', 'Quantazone Software  ...

# %%
detail=[]
for soup in soup2:
  detailList=soup.find_all('div',class_='individual_internship_internship')
  for i in detailList:
    detail.append(i)
# len(detail)

# %%
#print(detail[0])

# %%
location=[]
for i in detail:
  loc=i.find('a').text
  location.append(loc)
  #print(loc)
# print(len(location))
print(f"Locations are : {location}")
# Out:
# Locations are : ['Delhi', 'Patna', 'Gurgaon', 'Gurgaon', 'Jaipur', 'Work from home', 'Work from home', 'Work from home', 'Gurgaon', 'Work from home', 'Hyderabad', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Patna', 'Mumbai', 'Chandigarh', 'Ahmedabad', 'Work from home', 'Mumbai', 'Work from home', 'Work from home', 'Work from home', 'Bangalore', 'Delhi', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Mohali', 'Bangalore', 'Vadodara', 'Work from home', 'Cochin', 'Pune', 'Work from home', 'Vasai-Virar, Thane, Navi Mumbai, Mumbai, Mira Bhayandar', 'Mumbai', 'Ghaziabad, Noida, Delhi', 'Work from home', 'Patna', 'Work from home', 'Mumbai', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Greater Noida', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Noida', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Shahdara', 'Work from home', 'Noida', 'Work from home', 'Mumbai', 'Bangalore', 'Gurgaon', 'Work from home', 'Work from home', 'Delhi', 'Gurgaon', 'Chennai', 'Amravati, Ahmednagar, Kolkata, Patna, Akola, Aurangabad, Chennai, Delhi, Pune, Hyderabad, Mumbai, Baramati, Noida, Andhra Pradesh, Nashik', 'Work from home', 'Noida, Hyderabad, Mumbai, Pune, Surat, Patna, Kolkata, Faridabad, Chennai, Dehradun, Gurgaon, Ghaziabad, Delhi, Bangalore, Udaipur', 'Work from home', 'Coimbatore', 'Coimbatore', 'Delhi', 'Work from home', 'Work from home', 'Indore', 'Delhi', 'Hyderabad', 'Noida', 'Work from home', 'Work from home', 'Bangalore', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Delhi', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Noida', 'Work from home', 'Gurgaon', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Bangalore', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Mumbai', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Gurgaon', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Gurgaon', 'Work from home', 'Work from home', 'Work from home', 'Bangalore', 'Delhi', 'Gurgaon', 'Work from home', 'Delhi', 'Work from home', 'Ahmedabad', 'Work from home', 'Work from home', 'Delhi', 'Work from home', 'Chennai', 'Noida, Delhi, Greater Noida', 'Bangalore', 'Delhi', 'Gurgaon', 'Work from home', 'Work from home', 'Mohali', 'Bangalore', 'Work from home', 'Mumbai, Pune, Ahmedabad, Navi Mumbai, Bangalore', 'Bareilly, Udaipur', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Bangalore', 'Noida', 'Work from home', 'Bangalore', 'Work from home', 'Bangalore', 'Work from home', 'Work from home', 'Delhi', 'Bangalore, Koramangala', 'Sonipat', 'Hyderabad', 'Bangalore', 'Ahmedabad', 'Work from home', 'Gurgaon', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Bangalore', 'Bangalore', 'Work from home', 'Delhi, Gurgaon', 'Work from home', 'Work from home', 'Ahmedabad', 'Ahmedabad', 'Mumbai', 'Faridabad', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Pune', 'Delhi', 'Work from home', 'Meerut', 'Work from home', 'Work from home', 'Gurgaon', 'Chennai, Coimbatore, Madurai', 'Bangalore', 'Chennai, Coimbatore, Madurai', 'Work from home', 'Work from home', 'Coimbatore, Madurai, Chennai', 'Work from home', 'Work from home', 'Work from home', 'Mumbai', 'Jaipur', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work f ...

# %%
duration_detail1=[]
for soup in soup2:
  duraList=soup.find_all('div',class_='item_body')
  for i in duraList:
    duration_detail1.append(i)
duration=[]
i = 1
while i < len(duration_detail1):
  duration.append(duration_detail1[i].text.strip()[0])
  i +=3
# print(len(duration))
print(duration)
# Out:
# ['6', '6', '1', '6', '6', '6', '6', '3', '6', '6', '3', '2', '3', '6', '6', '6', '3', '6', '6', '6', '6', '1', '3', '3', '3', '2', '6', '6', '1', '5', '3', '3', '4', '6', '6', '4', '6', '2', '2', '3', '6', '6', '2', '6', '6', '2', '3', '3', '3', '6', '3', '6', '6', '3', '6', '1', '6', '2', '6', '2', '6', '2', '2', '3', '3', '5', '3', '3', '6', '6', '6', '5', '6', '6', '3', '5', '1', '6', '2', '6', '2', '1', '6', '3', '4', '3', '6', '6', '6', '6', '6', '3', '6', '2', '2', '3', '6', '2', '2', '6', '3', '2', '6', '6', '6', '2', '2', '6', '6', '3', '3', '6', '3', '6', '3', '1', '6', '3', '6', '6', '6', '6', '3', '3', '3', '6', '3', '3', '6', '3', '6', '6', '6', '6', '6', '6', '6', '3', '3', '6', '3', '6', '1', '2', '6', '6', '6', '6', '2', '2', '5', '6', '3', '3', '2', '6', '3', '6', '3', '2', '3', '2', '3', '6', '6', '2', '2', '3', '3', '2', '2', '6', '6', '6', '2', '6', '6', '3', '3', '2', '6', '6', '2', '3', '1', '3', '3', '3', '6', '4', '2', '1', '3', '2', '6', '3', '6', '4', '3', '4', '3', '3', '3', '6', '3', '6', '2', '1', '6', '6', '6', '3', '6', '6', '4', '6', '3', '6', '3', '6', '6', '6', '3', '2', '3', '6', '3', '6', '6', '6', '6', '6', '4', '1', '6', '2', '6', '6', '3', '6', '6', '4', '6', '1', '3', '3', '3', '3', '6', '2', '1', '1', '2', '3', '6', '3', '6', '6', '6', '4', '3', '2', '4', '6', '3', '2', '6', '2', '6', '2', '3', '4', '6', '3', '6', '3', '2', '6', '6', '6', '3', '6', '6', '2', '6', '6', '3', '6', '6', '3', '3', '4', '3', '6', '1', '3', '3', '5', '6', '6', '4', '3', '6', '2', '6', '6', '6', '6', '2', '6', '6', '6', '3', '6', '4', '6', '4', '3', '5', '6', '6', '3', '3', '3', '6', '2', '6', '6', '1', '1', '3', '3', '3', '3', '1', '3', '6', '6', '3', '2', '2', '5']

# %%
stipend=[]
for soup in soup2:
  stipList=soup.find_all('span',class_='stipend')
  for i in stipList:
    val=i.text
    stipend.append(val)
# print(len(stipend))
print(f"Stipend is : {stipend}")
# Out:
# Stipend is : ['₹ 7,000 /month', '₹ 5,000 /month', '₹ 10,000 /month', '₹ 15,000-18,000 /month', '₹ 5,000 /month', '₹ 5,000-8,000 /month', '₹ 5,000 /month', '₹ 3,000 /month', '₹ 15,000 /month', '₹ 10,000 /month', '₹ 10,000 /month', '₹ 4,000 /month', '₹ 5,000 /month', '₹ 10,000-15,000 /month', '₹ 5,000 /month', '₹ 5,000 /month', '₹ 10,000 /month', '₹ 5,000-10,000 /month', '₹ 9,000 /month', '₹ 8,000-15,000 /month', '₹ 5,000 /month', '₹ 2,000 /month', '₹ 10,000 /month', '₹ 5,000 /month', '₹ 8,000 /month', '₹ 12,000 /month', '₹ 35,000 /month', '₹ 10,000-25,000 /month', '₹ 8,000 /month', '₹ 3,000 /month', '₹ 10,000 /month', '₹ 7,000 /month', '₹ 12,000 /month', '₹ 8,000 /month', '₹ 20,000 /month', '₹ 2,000 /week +  Incentives', '₹ 5,000-10,000 /month', '₹ 2,000 /month', '₹ 15,000 /month', '₹ 15,000-20,000 /month', '₹ 10,000-20,000 /month', '₹ 8,000 /month', '₹ 10,000 /month', '₹ 15,000 /month', '₹ 6,000-10,000 /month', '₹ 10,000 /month', '₹ 6,500 /month', '$ 100 /month', '₹ 6,500 /month', '₹ 6,500 /month', '₹ 4,000-8,000 /month', '₹ 6,500 /month', '₹ 5,000-8,000 /month', '₹ 15,000 /month', '₹ 15,000 /month', '₹ 10,000 /month', '₹ 7,500 /month', '₹ 20,000 /month', '₹ 10,000-12,000 /month', '₹ 20,000 /month', '₹ 5,000 /month', '₹ 20,000 /month', '₹ 20,000 /month', '₹ 5,000 /month', '₹ 8,000 /month', '₹ 15,000 /month +  Incentives', '₹ 10,000 /month', '₹ 10,000-15,000 /month', '₹ 6,500 /month', '₹ 25,000 /month', '₹ 5,000-15,000 /month', '₹ 5,500 /month', '₹ 10,000 /month', '₹ 4,000-7,000 /month', '₹ 10,000 /month', '₹ 15,000-25,000 /month', '₹ 20,000 /month', '₹ 10,000-12,000 /month', '₹ 18,000 /month', '₹ 6,000-10,000 /month', '₹ 3,000 /month', '₹ 3,000 /month', '₹ 8,000 /month', '₹ 6,500 /month', '₹ 2,000-5,000 /week', '₹ 3,000-4,500 /month', '₹ 5,000 /month', '₹ 7,500 /month', '₹ 10,000 /month', '₹ 5,000 /month', '₹ 10,000 /month', '₹ 30,000-40,000 /month', '₹ 5,000-15,000 /month', '₹ 20,000 /month', '₹ 20,000 /month', '₹ 10,000-18,000 /month', '₹ 7,000-12,000 /month', '₹ 20,000 /month', '₹ 10,000 /month', '₹ 6,000-10,000 /month', '₹ 18,000-25,000 /month', '₹ 2,000 lump sum +  Incentives', '₹ 10,000 /month', '₹ 5,000 /month', '₹ 15,000 /month', '₹ 1,000 /month', '₹ 1,000 /month', '₹ 2,500 /month +  Incentives', '₹ 2,500 /month +  Incentives', '₹ 15,000-30,000 /month', '₹ 10,000-20,000 /month', '₹ 5,000-9,000 /month', '₹ 12,500 /month', '₹ 10,000-15,000 /month', '₹ 3,000 /month', '₹ 5,000 /month', '₹ 15,000 /month', '₹ 20,000-22,000 /month', '₹ 8,000-10,000 /month', '₹ 8,000-10,000 /month', '₹ 8,000-10,000 /month', '₹ 8,000-10,000 /month', '₹ 5,000 /month', '₹ 8,000-15,000 /month', '₹ 8,000-12,500 /month', '₹ 10,000-12,000 /month', '₹ 2,000 /month', '₹ 3,000-7,000 /month', '₹ 45,000 /month', '₹ 10,000-20,000 /month', '₹ 6,000-10,000 /month', '₹ 6,000-12,000 /month', '₹ 6,000-12,000 /month', '₹ 5,000-10,000 /month', '₹ 2,500 /month +  Incentives', '₹ 8,000-10,000 /month', '₹ 15,000 /month', '₹ 8,000-12,500 /month', '₹ 12,500 /month', '₹ 30,000 /month', '₹ 3,000 /month', '₹ 10,000-12,000 /month', '₹ 20,000 /month', '₹ 10,000 /month', '₹ 2,500 /month +  Incentives', '₹ 3,000-5,000 /month', '₹ 3,000 /month +  Incentives', '₹ 3,000 /month +  Incentives', '₹ 11,000 /month', '₹ 10,000 /month +  Incentives', '₹ 5,000 /month +  Incentives', '₹ 2,000 /month', '₹ 7,000-10,000 /month', '₹ 10,000 /month', '₹ 10,000-12,000 /month', '₹ 5,000-7,000 /month', '₹ 8,000 /month', '₹ 8,000 /month', '₹ 15,000 /month', '₹ 7,500 /month', '₹ 6,000-12,000 /month', '₹ 3,000 /month', '₹ 15,000 /month', '₹ 5,000-15,000 /month', '₹ 5,000-12,000 /month', '₹ 5,000-10,000 /month', '₹ 5,000 /month', '₹ 10,000-20,000 /month', '₹ 2,000-3,000 /month', '₹ 3,000-5,000 /month', '₹ 7,000-10,000 /month', '₹ 10,000 /month', '₹ 8,000 /month', '₹ 5,000 /month', '₹ 10,000-15,000 /month', '₹ 6,000-10,000 /month', '₹ 20,000-30,000 /month', '₹ 3,000 /month', '₹ 15,000 /month', '₹ 10,000 /month', '₹ 5,000 /month +  Incentives', '₹ 3,500 /month', '₹ 6,000-10,000 /month', '₹ 10,000 /mon ...

# %%
cont=[]
for soup in soup2:
  coutList=soup.find_all('div',class_='cta_container')
  for i in coutList:
    cont.append(i)

# %%
application_link=[]
for i in cont:
  anc=i.find('a')
  link=anc.get('href')
  #print(link)
  updated_link='https://internshala.com/'+link
  #print(updated_link)
  application_link.append(updated_link)
# print(len(application_link))
print(f"Application Link is : {application_link}")
# Out:
# Application Link is : ['https://internshala.com//internship/details/web-development-internship-in-delhi-at-stirring-minds1717089781', 'https://internshala.com//internship/details/php-development-internship-in-patna-at-ui-tech-lab-llp1717060764', 'https://internshala.com//internship/details/demo-post-internship-in-gurgaon-at-seven-arc-info-systems-llp1717050543', 'https://internshala.com//internship/details/flutter-development-internship-in-gurgaon-at-appyhigh-technology1716893809', 'https://internshala.com//internship/details/it-support-internship-in-jaipur-at-vigorous-healthtech-private-limited1716989244', 'https://internshala.com//internship/details/work-from-home-wordpress-development-internship-at-schnell-labs1716764370', 'https://internshala.com//internship/details/work-from-home-php-development-internship-at-ui-tech-lab-llp1717060835', 'https://internshala.com//internship/details/work-from-home-full-stack-php-developer-internship-at-brandzzy-softtech-private-limited1717052742', 'https://internshala.com//internship/details/flutter-development-internship-in-gurgaon-at-antino-labs-private-limited1716967841', 'https://internshala.com//internship/details/work-from-home-php-development-internship-at-ansh-intertrade-private-limited1717087665', 'https://internshala.com//internship/details/flutter-development-internship-in-hyderabad-at-repsoft-consultancy-services-private-limited1717072418', 'https://internshala.com//internship/details/work-from-home-shopify-developer-internship-at-axe-consultancy-and-security-services-llc1717067232', 'https://internshala.com//internship/details/work-from-home-wordpress-development-internship-at-shivam-arora1717066602', 'https://internshala.com//internship/details/work-from-home-e-commerce-web-app-development-using-next-js-react-js-and-node-js-internship-at-mymegaminds1717064427', 'https://internshala.com//internship/details/work-from-home-front-end-development-internship-at-ui-tech-lab-llp1717061257', 'https://internshala.com//internship/details/front-end-development-internship-in-patna-at-ui-tech-lab-llp1717060920', 'https://internshala.com//internship/details/augmented-reality-virtual-reality-developer-internship-in-mumbai-at-indian-institute-of-technology-bombay1717059487', 'https://internshala.com//internship/details/frontend-development-internship-in-chandigarh-at-globfluent-vidyatech-pvt-ltd1717058137', 'https://internshala.com//internship/details/php-development-internship-in-ahmedabad-at-evoort-solutions1717055389', 'https://internshala.com//internship/details/work-from-home-backend-development-internship-at-idea-usher1717055120', 'https://internshala.com//internship/details/full-stack-development-internship-in-mumbai-at-kvar-technologies-private-limited1717053243', 'https://internshala.com//internship/details/work-from-home-part-time-wordpress-development-internship-at-zenchi-softwares-opc-private-limited1717045909', 'https://internshala.com//internship/details/work-from-home-nodejs-development-internship-at-faclon1717053123', 'https://internshala.com//internship/details/work-from-home-part-time-wordpress-development-internship-at-aditya-raj1717052270', 'https://internshala.com//internship/details/front-end-development-internship-in-bangalore-at-baygrape-technology-solutions1717051802', 'https://internshala.com//internship/details/php-development-internship-in-delhi-at-international-institute-of-financial-markets-pratham1717051512', 'https://internshala.com//internship/details/work-from-home-web-development-internship-at-fyle1717050071', 'https://internshala.com//internship/details/work-from-home-laravel-development-internship-at-codalay1717010175', 'https://internshala.com//internship/details/work-from-home-php-development-internship-at-intella-education-private-limited1717008507', 'https://internshala.com//internship/details/work-from-home-project-manager-internship-at-godecor-technologies-private-limited1716994740', 'https://internshala.com//internship/details/work-from-home-blockcha ...

# %%
dataTable = {
    'profile': profile,
    "company": company,
    "location": location,
    "stipend":stipend,
    "duration": duration,
    "application Link": application_link
    }

df = pd.DataFrame(dataTable)
#print(f"""{len(profile)} {len(company)} {len(location)} {len(duration)} {len(stipend)} {len(application_link)}""")
# df

# %%
filename='internship_data_'+str(fieldname.replace(' ','_'))+'.csv'
print(filename)
# Out:
# internship_data_web_development.csv

# %%
df.to_csv(filename, index=False)

# %% [markdown]
# # New Section

# %% [markdown]
# Find Duration of each individual internship
# All the information u have got till now create a dataframe out of it using pandas
# Save the dataframe in CSV
# Create a general Code to fetch data from any number of page : 😉
#
# **Remember** : https://internshala.com/internships/analytics-internship/page-1/ and https://internshala.com/internships/analytics-internship/ both are same
