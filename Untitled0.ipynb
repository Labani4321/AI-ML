# %% [markdown]
# <a href="https://colab.research.google.com/github/Labani4321/AI-ML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/sample_data/california_housing_test.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.isnull()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2         False     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       population  households  median_income  median_house_value
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df["total_rooms"]
# Out:
# 0       3885.0
# 1       1510.0
# 2       3589.0
# 3         67.0
# 4       1241.0
#          ...
# 2995    1450.0
# 2996    5257.0
# 2997     956.0
# 2998      96.0
# 2999    1765.0
# Name: total_rooms, Length: 3000, dtype: float64

# %%
df.loc[0]
# Out:
# longitude               -122.0500
# latitude                  37.3700
# housing_median_age        27.0000
# total_rooms             3885.0000
# total_bedrooms           661.0000
# population              1537.0000
# households               606.0000
# median_income              6.6085
# median_house_value    344700.0000
# Name: 0, dtype: float64

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.size
# Out:
# 27000

# %%
df['population'].value_counts()
# Out:
# population
# 870.0     7
# 697.0     6
# 753.0     6
# 881.0     6
# 1211.0    6
#          ..
# 1415.0    1
# 1916.0    1
# 803.0     1
# 767.0     1
# 46.0      1
# Name: count, Length: 1802, dtype: int64

# %%
df[df["households"]>500]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 9       -118.02     34.08                31.0       2402.0           632.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 17      -121.20     38.69                26.0       3077.0           607.0
# ...         ...       ...                 ...          ...             ...
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2987    -121.97     37.29                25.0       4096.0           743.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df[df["households"]==500]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 31      -118.30     33.91                34.0       1617.0           493.0
# 636     -122.09     37.39                43.0       2065.0           535.0
# 796     -122.14     37.67                34.0       3036.0           533.0
# 1082    -118.01     34.08                30.0       2281.0           522.0
# 1463    -119.71     36.81                19.0       2282.0           550.0
# 1948    -118.50     34.16                34.0       3547.0           523.0
#
#       population  households  median_income  median_house_value
# 31        1530.0       500.0         2.6182            172600.0
# 636       1029.0       500.0         3.7318            327700.0
# 796       1366.0       500.0         4.2386            192300.0
# 1082      1969.0       500.0         3.6531            166300.0
# 1463      1034.0       500.0         1.6618             69700.0
# ...

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
url='https://internshala.com/'

# %%
from urllib.parse import urlencode
import requests
from bs4 import BeautifulSoup as bsp
import re
import pandas as pd

# %%
url='https://internshala.com/'

# %%
resp=requests.get(url)
print(resp)
# Out:
# <Response [200]>

# %%
print(resp.content)
# Out:
# b'<!DOCTYPE html>\n    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:fb="https://www.facebook.com/2008/fbml"\n        lang="en-US">\n\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=9" />\n    <meta charset="UTF-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1.0 user-scalable=0" />\n    <meta property="fb:app_id" content="702141670710132" />\n    <meta property="og:type" content="website" />\n            <meta property="og:image:width" content="1200" />\n        <meta property="og:image:height" content="630" />\n        <link rel="preload" href="https://internshala.com//static/images/home/sprites/img-assets.png" as="image"/>\n<link rel="preload" href="https://internshala.com//static/images/home/sprites/underline_fire.png"  as="image"/>\n    <link rel="preload" as="image" href="https://internshala.com/static/images/pgc_course_specific_banners/pgc_homepage_banner_new.png"/>\n    <link rel="preload" as="image" href
# ...
